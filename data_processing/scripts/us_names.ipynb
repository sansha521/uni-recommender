# %%
import pandas as pd

# %%
us_df = pd.read_csv("../datasets/us_uni_admission_metrics.csv")

# %%
us_names = us_df["school.name"]

# %%
us_names.head()
# Out:
# 0               Alabama A & M University
# 1    University of Alabama at Birmingham
# 2    University of Alabama in Huntsville
# 3               Alabama State University
# 4              The University of Alabama
# Name: school.name, dtype: str

# %%
us_names.to_csv("../datasets/us_names.csv", index=False)
